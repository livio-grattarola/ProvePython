# %%
[x + "_reg" for x in ["a", "B"] ]
# Out:
# ['a_reg', 'B_reg']

# %% [markdown]
# # DimProvince

# %%
# %load CarburanteUtility.py
import pandas as pd
def cu_readCsv(path, headerRow=0):
    if(headerRow == 0):
        return pd.read_csv(path, sep=";", keep_default_na=False, na_values=[''])
    return pd.read_csv(path, sep=";", keep_default_na=False, na_values=[''], header=headerRow);

# %%
#Lettura csv Regioni e Province
import pandas as pd
province = cu_readCsv("dati_carburante/Province.csv")
province.columns = ["Prov_" + x for x in province.columns]

regioni = cu_readCsv("dati_carburante/Regioni.csv");
regioni.columns = ["Reg_" + x for x in regioni.columns]

# %%
#Creazione csv DimProvince
import numpy as np
fullProvinces = province.merge(regioni, left_on=['Prov_CodiceIstatRegione'], right_on=['Reg_CodiceIstat'], how='left')
del fullProvinces['Prov_CodiceIstatCM']
del fullProvinces['Prov_CM']
del fullProvinces['Prov_CodiceIstatRegione']
del fullProvinces['Reg_Costiera']
fullProvinces = fullProvinces.rename({'Reg_Abbreviato': 'Reg_Short'})

fullProvinces.to_csv("./out/DimProvince.csv", sep=';', index=False)
#fullProvinces

# %%
import pandas as pd
df1 = cu_readCsv("dati_carburante/anagrafica_impianti_attivi-20170101.csv", headerRow=1);
print ("pompe1: " , df1.shape[0], df1.columns)
df2 = cu_readCsv("dati_carburante/anagrafica_impianti_attivi-20180630.csv", headerRow=1);
print ("pompe2: " ,  df2.shape[0] , df2.columns)
df2.columns
prezzi1 = cu_readCsv("dati_carburante/prezzo_alle_8-20170101.csv", headerRow=1);
print ("prezzi1: " , prezzi1.shape[0], prezzi1.columns)
# Out:
# pompe1:  20410 Index(['idImpianto', 'Gestore', 'Bandiera', 'Tipo Impianto', 'Nome Impianto',
#        'Indirizzo', 'Comune', 'Provincia', 'Latitudine', 'Longitudine'],
#       dtype='object')
# pompe2:  21298 Index(['idImpianto', 'Gestore', 'Bandiera', 'Tipo Impianto', 'Nome Impianto',
#        'Indirizzo', 'Comune', 'Provincia', 'Latitudine', 'Longitudine'],
#       dtype='object')
# prezzi1:  82577 Index(['idImpianto', 'descCarburante', 'prezzo', 'isSelf', 'dtComu'], dtype='object')

# %% [markdown]
# # Esperimenti

# %%
orig = df1
print(orig.shape)
dfg = orig.groupby(['Latitudine', 'Longitudine']).size().reset_index(name='counts')
dups = dfg[dfg['counts']  > 1]

part = dups.iloc[0:5, :].merge(orig, on= ['Latitudine', 'Longitudine'], suffixes=('_1', '_2'), how='inner')
cols = [x for x in prezzi1.columns]
cols.append('Bandiera')
cols.append('Latitudine')

part.merge(prezzi1, on= ['idImpianto'], suffixes=('_1', '_2'), how='inner')[cols]
#37.314926
#df1[ str(df1['Latitudine'] == '37.314926' ]
# Out:
# (20410, 10)
# %%
merged = df1.merge(df2, on= ['idImpianto', 'Gestore'], suffixes=('_1', '_2'), how='outer' )
merged[ merged['Bandiera_1'] != merged['Bandiera_2']]


mc = df1.merge(df2, on= ['Latitudine', 'Longitudine'], suffixes=('_1', '_2'), how='inner' )
mc.iloc[8692]
# Out:
# idImpianto_1                                    16789
# Gestore_1                   TRE PONTI FOOD OIL S.R.L.
# Bandiera_1                                     Api-Ip
# Tipo Impianto_1                                 Altro
# Nome Impianto_1                               Acerra
# Indirizzo_1         S.S.7 BIS - KM. 31,482 S.C. 80011
# Comune_1                                       ACERRA
# Provincia_1                                       NaN
# Latitudine                                    40.9623
# Longitudine                                   14.4282
# idImpianto_2                                    16789
# Gestore_2                   TRE PONTI FOOD OIL S.R.L.
# Bandiera_2                                     Api-Ip
# Tipo Impianto_2                                 Altro
# Nome Impianto_2                               Acerra
# Indirizzo_2         S.S.7 BIS - KM. 31,482 S.C. 80011
# Comune_2                                       ACERRA
# Provincia_2                                       NaN
# Name: 8692, dtype: object

# %%
mc.loc[(mc['Provincia_1'] != mc['Provincia_2']), ['Provincia_1', 'Provincia_2']]
# Out:
#      Provincia_1 Provincia_2
# 8692         NaN         NaN
# 8693         NaN         NaN
# 8694         NaN         NaN
# 8695         NaN         NaN
# 8696         NaN         NaN
# 8697         NaN         NaN
# 8698         NaN         NaN
# 8699         NaN         NaN
# 8700         NaN         NaN
# 8701         NaN         NaN
# 8702         NaN         NaN
# 8703         NaN         NaN
# 8704         NaN         NaN
# 8705         NaN         NaN
# 8706         NaN         NaN
# 8707         NaN         NaN
# 8708         NaN         NaN
# 8709         NaN         NaN
# 8710         NaN         NaN
# 8711         NaN         NaN
# 8712         NaN         NaN
# 8713         NaN         NaN
# 8714         NaN         NaN
# 8715         NaN         NaN
# 8716         NaN         NaN
# 8717         NaN         NaN
# 8718         NaN         NaN
# 8719         NaN         NaN
# 8720         NaN         NaN
# 8721         NaN         NaN
# ...          ...         ...
# 9177         NaN         NaN
# 9178         NaN         NaN
# 9179         NaN         NaN
# 9180         NaN         NaN
# 9181         NaN         NaN
# 9182         NaN         NaN
# 9183         NaN         NaN
# 9184         NaN         NaN
# 9185         NaN         NaN
# 9186         NaN         NaN
# 9187         NaN         NaN
# 9188         NaN         NaN
# 9189         NaN         NaN
# 9190         NaN         NaN
# 9191         NaN         NaN
# 9192         NaN         NaN
# 9193         NaN         NaN
# 9194         NaN         NaN
# 9195         NaN         NaN
# 9196         NaN         NaN
# 9197         NaN         NaN
# 9198         NaN         NaN
# 9199         NaN         NaN
# 9200         NaN         NaN
# 9201         NaN         NaN
# 9202         NaN         NaN
# 9203         NaN         NaN
# 9204         NaN         NaN
# 9205         NaN         NaN
# 9206         NaN         NaN
#
# [515 rows x 2 columns]
