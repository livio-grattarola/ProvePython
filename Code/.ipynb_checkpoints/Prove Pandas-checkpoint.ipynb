# %%
import pandas as pd
import matplotlib.pyplot as plt

#sites = pd.read_csv('resouces/anagrafica_impianti_attivi-500.csv' , sep=';')
sites = pd.read_csv('resouces/anagrafica_impianti_attivi-20180401.csv' , sep=';')

print(sites.columns)
#positions = sides.DataFrame[columns=('Longitudine')]
area = 1**2
sites.plot.scatter(x='Longitudine', y='Latitudine', s=area, figsize=(10, 10))
# Out:
# Index(['idImpianto', 'Gestore', 'Bandiera', 'Tipo Impianto', 'Nome Impianto',
#        'Indirizzo', 'Comune', 'Provincia', 'Latitudine', 'Longitudine'],
#       dtype='object')

# %%
'''
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([1,2,3,4], [5,6,7,8], 'bo')
plt.ylabel('some numbers')
plt.show()

df = pd.DataFrame([[5.1, 3.5, 0], [4.9, 3.0, 0], [7.0, 3.2, 1],
...                    [6.4, 3.2, 1], [5.9, 3.0, 2]],
...                   columns=['length', 'width', 'species'])
ax1 = df.plot.scatter(x='length',
...                       y='width',
...                       c='DarkBlue')
'''
# Out:
#   File "<ipython-input-28-f1113007ef8c>", line 10
#     ...                   columns=['length', 'width', 'species'])
#                                 ^
# SyntaxError: invalid syntax
